# %% [markdown]
# <a href="https://colab.research.google.com/github/omkarshisode/LGM-Intenship/blob/main/Task_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Name:-Omkar shisode**

# %% [markdown]
# # **LGMVIP-DataScience**

# %% [markdown]
# ## **Task 2:-Image to Pencil Sketch with Python**

# %%
from google.colab.patches import cv2_imshow

# %%
import numpy as np 
import cv2
img=cv2.imread("/content/ironman.jpg")

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=205x246 at 0x7F9178D70890>

# %%
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_img)
# Out:
# <PIL.Image.Image image mode=L size=205x246 at 0x7F9177D04DD0>

# %%
inverted_img = 255 - gray_img
cv2_imshow(inverted_img)
# Out:
# <PIL.Image.Image image mode=L size=205x246 at 0x7F9178D70990>

# %%
blurred = cv2.GaussianBlur(inverted_img, (21, 21), 0)

# %%
inverted_blurred = 255 - blurred
pencil_sketch = cv2.divide(gray_img, inverted_blurred, scale=256.0)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=205x246 at 0x7F9178D5E610>

# %%
cv2_imshow(img)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=RGB size=205x246 at 0x7F9178D70F90>
# <PIL.Image.Image image mode=L size=205x246 at 0x7F9178D70550>
